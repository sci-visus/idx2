# %%
import sys
sys.path.insert(0, '../../build/install')
import idx2Py as i2p
import numpy as np
from matplotlib import pyplot as plt
from ipywidgets import *

# %%
# %%time
input_file = 'F:/Workspace/idx2/build/Source/Applications/RelWithDebInfo/llc2160/u.idx2'
input_dir  = 'F:/Workspace/idx2/build/Source/Applications/RelWithDebInfo'
level = 2
sublevel = 7
accuracy = 0.01
array1 = i2p.Decode3f32(input_file, input_dir, level, sublevel, accuracy)
print(array1.shape)
print('7.5 MB')
# Out:
# (8, 1620, 540)
# 7.5 MB
# CPU times: total: 4.2 s
# Wall time: 4.2 s

# %%
# %%time
input_file = 'F:/Workspace/idx2/build/Source/Applications/RelWithDebInfo/llc2160/u.idx2'
input_dir  = 'F:/Workspace/idx2/build/Source/Applications/RelWithDebInfo'
level = 1
sublevel = 7
accuracy = 0.01
array2 = i2p.Decode3f32(input_file, input_dir, level, sublevel, accuracy)
print(array2.shape)
print('22 MB')
# Out:
# (16, 3240, 1080)
# 22 MB
# CPU times: total: 17.6 s
# Wall time: 17.6 s

# %%
# %%time
input_file = 'F:/Workspace/idx2/build/Source/Applications/RelWithDebInfo/llc2160/u.idx2'
input_dir  = 'F:/Workspace/idx2/build/Source/Applications/RelWithDebInfo'
level = 0
sublevel = 7
accuracy = 0.0000001
array3 = i2p.Decode3f32(input_file, input_dir, level, sublevel, accuracy)
print(array3.shape)
print('650 MB')
# Out:
# (32, 6480, 2160)
# 650 MB
# CPU times: total: 1min 50s
# Wall time: 1min 50s

# %%
# %matplotlib inline
fig, ((ax1, ax2, ax3)) = plt.subplots(1, 3, figsize=([12, 12]))
#fig = plt.figure(figsize = (4, 12))
plot1 = ax1.imshow(array1[0, :, :], origin = 'lower', cmap = 'tab20c', aspect = 'auto', vmin=-6.14770936965942382812, vmax=1.24035537242889404297)
plot2 = ax2.imshow(array2[0, :, :], origin = 'lower', cmap = 'tab20c', aspect = 'auto', vmin=-6.14770936965942382812, vmax=1.24035537242889404297)
plot3 = ax3.imshow(array3[0, :, :], origin = 'lower', cmap = 'tab20c', aspect = 'auto', vmin=-6.14770936965942382812, vmax=1.24035537242889404297)
plt.show()


#interact(f, t = widgets.IntSlider(min = 0, max = array1.shape[0] - 1, step = 1, value = 0, layout = Layout(width = '500px')));

# %%
avg = np.sum(array2, 0) / array2.shape[0]
fig = plt.figure(figsize = (4, 12))
plot = plt.imshow(avg, origin = 'lower', cmap = 'tab20c', aspect = 'auto', vmin=-6.14770936965942382812, vmax=1.24035537242889404297)
plt.show()
